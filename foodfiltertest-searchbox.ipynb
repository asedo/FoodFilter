# %% [markdown]
# ##Development Status:
#
# This is my attempt on adding a searchbox.
# I got the searchbox to appear but it does not seem to work.
#
# The goal is to add a text box to select items containing a particular string.
# 	- For example, to search all instances where the "Shrt_Desc" field contains the string "Kayle"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from bokeh.layouts import row, widgetbox
from bokeh.models import CustomJS, Slider, HoverTool, BoxAnnotation
from bokeh.models.widgets import Slider, Select, TextInput
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from collections import OrderedDict

#from plotly.offline import download_plotlyjs, init_notebook_mode, plot
#from plotly.graph_objs import *


#%matplotlib inline
#init_notebook_mode()

# %%
dffile = "./Data/sr28abxl/ABBREV_FoodDatabase.xlsx"
dvfile = "./Playdata.xlsx"
#df = pd.read_excel(file, sheetname = 'Sheet1', header = 0, index_col = 0, convert_float = True)
#dv = pd.read_excel(file, sheetname = 'Sheet3', header = 0, index_col = 0, convert_float = True)
df = pd.read_excel(dffile, sheetname = 'ABBREV', header = 0, convert_float = True)
dv = pd.read_excel(dvfile, sheetname = 'Sheet3', header = 0, index_col = 0, convert_float = True)
df.columns = df.dtypes.index.str.replace("(", "").str.replace(")", "").str.replace("µ", "p")

Searchstring = "SHAKE|BEVERAGES|LIQUOR|FORMULA|BABY|SALTED|UNSWTND|PDR|FREEZE|GENERAL MILLS|FRUIT-FLAV|CEREALS|SNACKFO|OIL,|LARD|CANDIES|YEAST|SNACKS|BACKFAT|SHORTENING|COOKIES|BASIL,DRIED|SYRUP"
df = df[df.Shrt_Desc.str.contains(Searchstring) == False]
#dffout = dff[dff.Shrt_Desc.str.contains(Searchstring) == True]

#foodgroups = ['Bread','Candy', 'Dessert','Dressing','Fruit','Meat','Pasta','Pizza','Spread','Vegetable','fruit'}
#  This file can be used to calculate nutrient values for food portions from the
#values provided per 100 g of food. The following formula is used to calculate the nutrient
#content per household measure:
#N = (V*W)/100
#where:
#N = nutrient value per household measure,
#V = nutrient value per 100 g (Nutr_Val in the Nutrient Data file), and
#W = g weight of portion (Gm_Wgt in the Weight file).

df['protein_rda'] = df['Protein_g']/dv['DV']['Protein'] * (df['GmWt_1']/100)
df['Calories_rda'] = df['Energ_Kcal']/dv['DV']['Caloriesm'] * (df['GmWt_1']/100)
df['Calories'] = df['Energ_Kcal'] * (df['GmWt_1']/100)
#df['foodtext'] = df.Shrt_Desc 
df['Totfat_rda'] = df['Lipid_Tot_g']/dv['DV']['Total Fat']  * (df['GmWt_1']/100)
df['Satfat_rda'] = df['FA_Sat_g']/dv['DV']['Saturated Fat']  * (df['GmWt_1']/100)
df['Colesterol_rda'] = df['Cholestrl_mg']/dv['DV']['Cholesterol']  * (df['GmWt_1']/100)
df['Potassium_rda'] = df['Potassium_mg']/dv['DV']['Potassium'] * (df['GmWt_1']/100)
df['Sodium_rda'] = df['Sodium_mg']/dv['DV']['Sodium']  * (df['GmWt_1']/100)
#df['TotCarbs_rda'] = df['Lipid_Tot_g']/dv['DV']['Total Carbohydrate']  * (df['GmWt_1']/100)
df['Dietfiber_rda'] = df['Fiber_TD_g']/dv['DV']['Dietary Fiber']  * (df['GmWt_1']/100)
df['VitaminA_rda'] = df['Vit_A_IU']/dv['DV']['Vitamin A']  * (df['GmWt_1']/100)
df['VitaminC_rda'] = df['Vit_C_mg']/dv['DV']['Vitamin C'] * (df['GmWt_1']/100)
df['Calcium_rda'] = df['Calcium_mg']/dv['DV']['Calcium']  * (df['GmWt_1']/100)
df['Iron_rda'] = df['Iron_mg']/dv['DV']['Iron']  * (df['GmWt_1']/100)
df['VitaminD_rda'] = df['Vit_D_pg']/dv['DV']['Vitamin D']  * (df['GmWt_1']/100)
df['VitaminE_rda'] = df['Vit_E_mg']/dv['DV']['Vitamin E']  * (df['GmWt_1']/100)
df['VitaminK_rda'] = df['Vit_K_pg']/dv['DV']['Vitamin K']  * (df['GmWt_1']/100)
df['Thiamin_rda'] = df['Thiamin_mg']/dv['DV']['Thiamin']  * (df['GmWt_1']/100)
df['Riboflavin_rda'] = df['Riboflavin_mg']/dv['DV']['Riboflavin']  * (df['GmWt_1']/100)
df['Niacin_rda'] = df['Niacin_mg']/dv['DV']['Niacin']  * (df['GmWt_1']/100)
df['VitaminB6_rda'] = df['Vit_B6_mg']/dv['DV']['Vitamin B6']  * (df['GmWt_1']/100)
df['Folate_rda'] = df['Folate_Tot_pg']/dv['DV']['Folate']  * (df['GmWt_1']/100)
df['VitaminB12_rda'] = df['Vit_B12_pg']/dv['DV']['Vitamin B12']  * (df['GmWt_1']/100)
df['PantothenicAcid_rda'] = df['Panto_Acid_mg']/dv['DV']['Pantothenic acid']  * (df['GmWt_1']/100)
df['Phosphorus_rda'] = df['Phosphorus_mg']/dv['DV']['Phosphorus']  * (df['GmWt_1']/100)
df['Magnesium_rda'] = df['Magnesium_mg']/dv['DV']['Magnesium']  * (df['GmWt_1']/100)
df['Zinc_rda'] = df['Zinc_mg']/dv['DV']['Zinc']  * (df['GmWt_1']/100)
df['Selenium_rda'] = df['Selenium_pg']/dv['DV']['Selenium']  * (df['GmWt_1']/100)
df['Copper_rda'] = df['Copper_mg']/dv['DV']['Copper']  * (df['GmWt_1']/100)
df['Manganese_rda'] = df['Manganese_mg']/dv['DV']['Manganese']  * (df['GmWt_1']/100)
df['Molybdenum_rda'] = df['Energ_Kcal']/dv['DV']['Molybdenum']  * (df['GmWt_1']/100)
##df["Quantity"] = df["GmWt_1"].map(str) + " @ " + df["GmWt_Desc1"] 
df["Quantity"] = df["GmWt_Desc1"] 
 
df['Healthy'] = df['protein_rda']+ df['Dietfiber_rda']+ df['Thiamin_rda'] + df['Riboflavin_rda'] + df['Niacin_rda']  + df['PantothenicAcid_rda'] + df['Phosphorus_rda'] + df['Magnesium_rda'] + df['Selenium_rda'] + df['Copper_rda'] + df['Manganese_rda'] + df['Molybdenum_rda']  + (df['VitaminA_rda'] + df['VitaminB6_rda'] + df['VitaminC_rda'] + df['Calcium_rda'] + df['Iron_rda'] + df['VitaminD_rda'] + df['VitaminE_rda'] + df['VitaminK_rda'] + df['Folate_rda'] + df['VitaminB12_rda'] + df['Zinc_rda'])*2 - (10*df['Sodium_rda']) 


#df['Calories_rda']+ df['Totfat_rda']+df['Satfat_rda']+df['Colesterol_rda'] +df['Sodium_rda'] +df['TotCarbs_rda']+

#foodgrp_key= list(set(df['foodgroup']))
#grp_val = list(map(int,range(len(foodgrp_key))))
#grpdict = dict(zip(foodgrp_key,grp_val))
#df.head()

#Get rid of the NaNs
dff = df[np.isfinite(df['Healthy'])]
#FiFORMULAstrings in dffin and dFORMULA
dffin = dff
#Searchstring = "SHAKE|BEVERAGES|LIQUOR|FORMULA|BABY|SALTED|UNSWTND|PDR|FREEZE|GENERAL MILLS|FRUIT-FLAV|CEREALS|SNACKFO|OIL,|LARD|CANDIES|YEAST|SNACKS|BACKFAT|SHORTENING|COOKIES|BASIL,DRIED|SYRUP"
#dffin = dff[dff.Shrt_Desc.str.contains(Searchstring) == False]
#dffout = dff[dff.Shrt_Desc.str.contains(Searchstring) == True]

# %%
# Create a dictionary out of the dataframe so we can select them later
dffin.set_index("Shrt_Desc", drop=True, inplace=True)
dictionary = df.to_dict(orient="index")
dictionary
# Out:
# {0: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 2.11,
#   'Beta_Carot_pg': 158.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 24.0,
#   'Calcium_rda': 0.0012000000000000001,
#   'Calories': 35.85,
#   'Calories_rda': 0.017925,
#   'Carbohydrt_g': 0.06,
#   'Cholestrl_mg': 215.0,
#   'Choline_Tot_ mg': 18.8,
#   'Colesterol_rda': 0.035833333333333335,
#   'Copper_mg': 0.0,
#   'Copper_rda': 0.0,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 717,
#   'FA_Mono_g': 21.021,
#   'FA_Poly_g': 3.043,
#   'FA_Sat_g': 51.368,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 3.0,
#   'Folate_Tot_pg': 3.0,
#   'Folate_rda': 0.000375,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 3.0,
#   'GmWt_1': 5.0,
#   'GmWt_2': 14.2,
#   'GmWt_Desc1': '1 pat,  (1" sq, 1/3" high)',
#   'GmWt_Desc2': '1 tbsp',
#   'Healthy': 0.42218539682539685,
#   'Iron_mg': 0.02,
#   'Iron_rda': 5.555555555555556e-05,
#   'Lipid_Tot_g': 81.11,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 2.0,
#   'Magnesium_rda': 0.00025,
#   'Manganese_mg': 0.0,
#   'Manganese_rda': 0.0,
#   'Molybdenum_rda': 0.47800000000000004,
#   'NDB_No': 1001,
#   'Niacin_mg': 0.042,
#   'Niacin_rda': 0.00010500000000000002,
#   'Panto_Acid_mg': 0.11,
#   'PantothenicAcid_rda': 0.00055,
#   'Phosphorus_mg': 24.0,
#   'Phosphorus_rda': 0.0012000000000000001,
#   'Potassium_mg': 24.0,
#   'Potassium_rda': 0.00034285714285714285,
#   'Protein_g': 0.85,
#   'Quantity': '1 pat,  (1" sq, 1/3" high)',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 671.0,
#   'Riboflavin_mg': 0.034,
#   'Riboflavin_rda': 0.001,
#   'Satfat_rda': 0.12842,
#   'Selenium_pg': 1.0,
#   'Selenium_rda': 0.0007142857142857143,
#   'Shrt_Desc': 'BUTTER,WITH SALT',
#   'Sodium_mg': 643.0,
#   'Sodium_rda': 0.013395833333333336,
#   'Sugar_Tot_g': 0.06,
#   'Thiamin_mg': 0.005,
#   'Thiamin_rda': 0.0001666666666666667,
#   'Totfat_rda': 0.06239230769230769,
#   'Vit_A_IU': 2499.0,
#   'Vit_A_RAE': 684.0,
#   'Vit_B12_pg': 0.17,
#   'Vit_B6_mg': 0.003,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 2.32,
#   'Vit_K_pg': 7.0,
#   'VitaminA_rda': 0.024990000000000002,
#   'VitaminB12_rda': 0.0014166666666666668,
#   'VitaminB6_rda': 7.500000000000001e-05,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.0038666666666666663,
#   'VitaminK_rda': 0.0043749999999999995,
#   'Water_g': 15.87,
#   'Zinc_mg': 0.09,
#   'Zinc_rda': 0.00030000000000000003,
#   'protein_rda': 0.0008500000000000001},
#  1: {'Alpha_Carot_pg': 1.0,
#   'Ash_g': 1.62,
#   'Beta_Carot_pg': 135.0,
#   'Beta_Crypt_pg': 6.0,
#   'Calcium_mg': 23.0,
#   'Calcium_rda': 0.000874,
#   'Calories': 27.284,
#   'Calories_rda': 0.013642,
#   'Carbohydrt_g': 2.87,
#   'Cholestrl_mg': 225.0,
#   'Choline_Tot_ mg': 18.8,
#   'Colesterol_rda': 0.028499999999999998,
#   'Copper_mg': 0.01,
#   'Copper_rda': 0.00019,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 718,
#   'FA_Mono_g': 19.874,
#   'FA_Poly_g': 3.331,
#   'FA_Sat_g': 45.39,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 4.0,
#   'Folate_Tot_pg': 4.0,
#   'Folate_rda': 0.00038,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 4.0,
#   'GmWt_1': 3.8,
#   'GmWt_2': 9.4,
#   'GmWt_Desc1': '1 pat,  (1" sq, 1/3" high)',
#   'GmWt_Desc2': '1 tbsp',
#   'Healthy': 0.3246024326797386,
#   'Iron_mg': 0.05,
#   'Iron_rda': 0.00010555555555555555,
#   'Lipid_Tot_g': 78.3,
#   'Lut+Zea_ pg': 13.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 1.0,
#   'Magnesium_rda': 9.5e-05,
#   'Manganese_mg': 0.001,
#   'Manganese_rda': 1.9e-05,
#   'Molybdenum_rda': 0.3637866666666667,
#   'NDB_No': 1002,
#   'Niacin_mg': 0.022,
#   'Niacin_rda': 4.179999999999999e-05,
#   'Panto_Acid_mg': 0.097,
#   'PantothenicAcid_rda': 0.0003686,
#   'Phosphorus_mg': 24.0,
#   'Phosphorus_rda': 0.000912,
#   'Potassium_mg': 41.0,
#   'Potassium_rda': 0.0004451428571428571,
#   'Protein_g': 0.49,
#   'Quantity': '1 pat,  (1" sq, 1/3" high)',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 671.0,
#   'Riboflavin_mg': 0.064,
#   'Riboflavin_rda': 0.0014305882352941177,
#   'Satfat_rda': 0.086241,
#   'Selenium_pg': 0.0,
#   'Selenium_rda': 0.0,
#   'Shrt_Desc': 'BUTTER,WHIPPED,W/ SALT',
#   'Sodium_mg': 583.0,
#   'Sodium_rda': 0.009230833333333334,
#   'Sugar_Tot_g': 0.06,
#   'Thiamin_mg': 0.007,
#   'Thiamin_rda': 0.00017733333333333335,
#   'Totfat_rda': 0.045775384615384614,
#   'Vit_A_IU': 2468.0,
#   'Vit_A_RAE': 683.0,
#   'Vit_B12_pg': 0.07,
#   'Vit_B6_mg': 0.008,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 1.37,
#   'Vit_K_pg': 4.6,
#   'VitaminA_rda': 0.0187568,
#   'VitaminB12_rda': 0.00044333333333333334,
#   'VitaminB6_rda': 0.000152,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.0017353333333333333,
#   'VitaminK_rda': 0.002185,
#   'Water_g': 16.72,
#   'Zinc_mg': 0.05,
#   'Zinc_rda': 0.00012666666666666666,
#   'protein_rda': 0.0003724},
#  3: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 5.11,
#   'Beta_Carot_pg': 74.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 528.0,
#   'Calcium_rda': 0.14968800000000002,
#   'Calories': 100.0755,
#   'Calories_rda': 0.050037750000000006,
#   'Carbohydrt_g': 2.34,
#   'Cholestrl_mg': 75.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.07087500000000001,
#   'Copper_mg': 0.04,
#   'Copper_rda': 0.0056700000000000006,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 353,
#   'FA_Mono_g': 7.778,
#   'FA_Poly_g': 0.8,
#   'FA_Sat_g': 18.669,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 36.0,
#   'Folate_Tot_pg': 36.0,
#   'Folate_rda': 0.025515000000000003,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 36.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': 17.0,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': '1 cubic inch',
#   'Healthy': 1.1535312176470596,
#   'Iron_mg': 0.31,
#   'Iron_rda': 0.0048825000000000006,
#   'Lipid_Tot_g': 28.74,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 23.0,
#   'Magnesium_rda': 0.016301250000000003,
#   'Manganese_mg': 0.009,
#   'Manganese_rda': 0.00127575,
#   'Molybdenum_rda': 1.3343400000000003,
#   'NDB_No': 1004,
#   'Niacin_mg': 1.016,
#   'Niacin_rda': 0.014401800000000001,
#   'Panto_Acid_mg': 1.729,
#   'PantothenicAcid_rda': 0.04901715,
#   'Phosphorus_mg': 387.0,
#   'Phosphorus_rda': 0.10971450000000002,
#   'Potassium_mg': 256.0,
#   'Potassium_rda': 0.020736000000000004,
#   'Protein_g': 21.4,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 192.0,
#   'Riboflavin_mg': 0.382,
#   'Riboflavin_rda': 0.06370411764705884,
#   'Satfat_rda': 0.26463307500000005,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,BLUE',
#   'Sodium_mg': 1146.0,
#   'Sodium_rda': 0.13537125,
#   'Sugar_Tot_g': 0.5,
#   'Thiamin_mg': 0.029,
#   'Thiamin_rda': 0.005481000000000001,
#   'Totfat_rda': 0.1253506153846154,
#   'Vit_A_IU': 721.0,
#   'Vit_A_RAE': 198.0,
#   'Vit_B12_pg': 1.22,
#   'Vit_B6_mg': 0.166,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 21.0,
#   'Vit_D_pg': 0.5,
#   'Vit_E_mg': 0.25,
#   'Vit_K_pg': 2.4,
#   'VitaminA_rda': 0.040880700000000006,
#   'VitaminB12_rda': 0.05764500000000001,
#   'VitaminB6_rda': 0.023530500000000003,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00035437500000000004,
#   'VitaminE_rda': 0.0023625,
#   'VitaminK_rda': 0.008505,
#   'Water_g': 42.41,
#   'Zinc_mg': 2.66,
#   'Zinc_rda': 0.050274000000000006,
#   'protein_rda': 0.12133800000000002},
#  4: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 3.18,
#   'Beta_Carot_pg': 76.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 674.0,
#   'Calcium_rda': 0.8896800000000001,
#   'Calories': 489.72,
#   'Calories_rda': 0.24486000000000002,
#   'Carbohydrt_g': 2.79,
#   'Cholestrl_mg': 94.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.4136,
#   'Copper_mg': 0.024,
#   'Copper_rda': 0.01584,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 371,
#   'FA_Mono_g': 8.598,
#   'FA_Poly_g': 0.784,
#   'FA_Sat_g': 18.764,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 20.0,
#   'Folate_Tot_pg': 20.0,
#   'Folate_rda': 0.066,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 20.0,
#   'GmWt_1': 132.0,
#   'GmWt_2': 113.0,
#   'GmWt_Desc1': '1 cup, diced',
#   'GmWt_Desc2': '1 cup, shredded',
#   'Healthy': 9.116656414565828,
#   'Iron_mg': 0.43,
#   'Iron_rda': 0.03153333333333334,
#   'Lipid_Tot_g': 29.68,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 24.0,
#   'Magnesium_rda': 0.0792,
#   'Manganese_mg': 0.012,
#   'Manganese_rda': 0.00792,
#   'Molybdenum_rda': 6.5296,
#   'NDB_No': 1005,
#   'Niacin_mg': 0.118,
#   'Niacin_rda': 0.007788,
#   'Panto_Acid_mg': 0.288,
#   'PantothenicAcid_rda': 0.038016,
#   'Phosphorus_mg': 451.0,
#   'Phosphorus_rda': 0.5953200000000001,
#   'Potassium_mg': 136.0,
#   'Potassium_rda': 0.05129142857142857,
#   'Protein_g': 23.24,
#   'Quantity': '1 cup, diced',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 286.0,
#   'Riboflavin_mg': 0.351,
#   'Riboflavin_rda': 0.27254117647058823,
#   'Satfat_rda': 1.238424,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.27342857142857147,
#   'Shrt_Desc': 'CHEESE,BRICK',
#   'Sodium_mg': 560.0,
#   'Sodium_rda': 0.308,
#   'Sugar_Tot_g': 0.51,
#   'Thiamin_mg': 0.014,
#   'Thiamin_rda': 0.012320000000000001,
#   'Totfat_rda': 0.6027323076923077,
#   'Vit_A_IU': 1080.0,
#   'Vit_A_RAE': 292.0,
#   'Vit_B12_pg': 1.26,
#   'Vit_B6_mg': 0.065,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 22.0,
#   'Vit_D_pg': 0.5,
#   'Vit_E_mg': 0.26,
#   'Vit_K_pg': 2.5,
#   'VitaminA_rda': 0.28512,
#   'VitaminB12_rda': 0.2772,
#   'VitaminB6_rda': 0.0429,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0016500000000000002,
#   'VitaminE_rda': 0.01144,
#   'VitaminK_rda': 0.04125,
#   'Water_g': 41.11,
#   'Zinc_mg': 2.6,
#   'Zinc_rda': 0.22880000000000003,
#   'protein_rda': 0.613536},
#  5: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 2.7,
#   'Beta_Carot_pg': 9.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 184.0,
#   'Calcium_rda': 0.052164,
#   'Calories': 94.68900000000001,
#   'Calories_rda': 0.047344500000000005,
#   'Carbohydrt_g': 0.45,
#   'Cholestrl_mg': 100.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.0945,
#   'Copper_mg': 0.019,
#   'Copper_rda': 0.0026932500000000003,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 334,
#   'FA_Mono_g': 8.013,
#   'FA_Poly_g': 0.826,
#   'FA_Sat_g': 17.41,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 65.0,
#   'Folate_Tot_pg': 65.0,
#   'Folate_rda': 0.046068750000000006,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 65.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': 144.0,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': '1 cup, sliced',
#   'Healthy': 1.5091784470588236,
#   'Iron_mg': 0.5,
#   'Iron_rda': 0.007875,
#   'Lipid_Tot_g': 27.68,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 20.0,
#   'Magnesium_rda': 0.014175000000000002,
#   'Manganese_mg': 0.034,
#   'Manganese_rda': 0.004819500000000001,
#   'Molybdenum_rda': 1.26252,
#   'NDB_No': 1006,
#   'Niacin_mg': 0.38,
#   'Niacin_rda': 0.005386500000000001,
#   'Panto_Acid_mg': 0.69,
#   'PantothenicAcid_rda': 0.0195615,
#   'Phosphorus_mg': 188.0,
#   'Phosphorus_rda': 0.053298000000000005,
#   'Potassium_mg': 152.0,
#   'Potassium_rda': 0.012312000000000002,
#   'Protein_g': 20.75,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 173.0,
#   'Riboflavin_mg': 0.52,
#   'Riboflavin_rda': 0.08671764705882355,
#   'Satfat_rda': 0.24678675000000003,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,BRIE',
#   'Sodium_mg': 629.0,
#   'Sodium_rda': 0.07430062500000001,
#   'Sugar_Tot_g': 0.45,
#   'Thiamin_mg': 0.07,
#   'Thiamin_rda': 0.013230000000000002,
#   'Totfat_rda': 0.12072738461538463,
#   'Vit_A_IU': 592.0,
#   'Vit_A_RAE': 174.0,
#   'Vit_B12_pg': 1.65,
#   'Vit_B6_mg': 0.235,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 20.0,
#   'Vit_D_pg': 0.5,
#   'Vit_E_mg': 0.24,
#   'Vit_K_pg': 2.3,
#   'VitaminA_rda': 0.0335664,
#   'VitaminB12_rda': 0.0779625,
#   'VitaminB6_rda': 0.03331125,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00035437500000000004,
#   'VitaminE_rda': 0.0022680000000000005,
#   'VitaminK_rda': 0.008150625,
#   'Water_g': 48.42,
#   'Zinc_mg': 2.38,
#   'Zinc_rda': 0.044982,
#   'protein_rda': 0.11765250000000001},
#  6: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 3.68,
#   'Beta_Carot_pg': 12.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 388.0,
#   'Calcium_rda': 0.10999800000000001,
#   'Calories': 85.05000000000001,
#   'Calories_rda': 0.042525,
#   'Carbohydrt_g': 0.46,
#   'Cholestrl_mg': 72.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.06804,
#   'Copper_mg': 0.021,
#   'Copper_rda': 0.0029767500000000007,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 300,
#   'FA_Mono_g': 7.023,
#   'FA_Poly_g': 0.724,
#   'FA_Sat_g': 15.259,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 62.0,
#   'Folate_Tot_pg': 62.0,
#   'Folate_rda': 0.0439425,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 62.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': 246.0,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': '1 cup',
#   'Healthy': 1.2727075764705882,
#   'Iron_mg': 0.33,
#   'Iron_rda': 0.005197500000000001,
#   'Lipid_Tot_g': 24.26,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 20.0,
#   'Magnesium_rda': 0.014175000000000002,
#   'Manganese_mg': 0.038,
#   'Manganese_rda': 0.005386500000000001,
#   'Molybdenum_rda': 1.1340000000000001,
#   'NDB_No': 1007,
#   'Niacin_mg': 0.63,
#   'Niacin_rda': 0.00893025,
#   'Panto_Acid_mg': 1.364,
#   'PantothenicAcid_rda': 0.038669400000000013,
#   'Phosphorus_mg': 347.0,
#   'Phosphorus_rda': 0.0983745,
#   'Potassium_mg': 187.0,
#   'Potassium_rda': 0.015147000000000002,
#   'Protein_g': 19.8,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 240.0,
#   'Riboflavin_mg': 0.488,
#   'Riboflavin_rda': 0.08138117647058823,
#   'Satfat_rda': 0.21629632500000004,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,CAMEMBERT',
#   'Sodium_mg': 842.0,
#   'Sodium_rda': 0.09946125000000001,
#   'Sugar_Tot_g': 0.46,
#   'Thiamin_mg': 0.028,
#   'Thiamin_rda': 0.005292000000000001,
#   'Totfat_rda': 0.1058109230769231,
#   'Vit_A_IU': 820.0,
#   'Vit_A_RAE': 241.0,
#   'Vit_B12_pg': 1.3,
#   'Vit_B6_mg': 0.227,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 18.0,
#   'Vit_D_pg': 0.4,
#   'Vit_E_mg': 0.21,
#   'Vit_K_pg': 2.0,
#   'VitaminA_rda': 0.04649400000000001,
#   'VitaminB12_rda': 0.06142500000000001,
#   'VitaminB6_rda': 0.032177250000000004,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00028350000000000006,
#   'VitaminE_rda': 0.0019845,
#   'VitaminK_rda': 0.007087500000000001,
#   'Water_g': 51.8,
#   'Zinc_mg': 2.38,
#   'Zinc_rda': 0.044982,
#   'protein_rda': 0.11226600000000002},
#  7: {'Alpha_Carot_pg': nan,
#   'Ash_g': 3.28,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 673.0,
#   'Calcium_rda': 0.19079550000000003,
#   'Calories': 106.59600000000002,
#   'Calories_rda': 0.053298000000000005,
#   'Carbohydrt_g': 3.06,
#   'Cholestrl_mg': 93.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.087885,
#   'Copper_mg': 0.024,
#   'Copper_rda': 0.0034020000000000005,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 376,
#   'FA_Mono_g': 8.275,
#   'FA_Poly_g': 0.83,
#   'FA_Sat_g': 18.584,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 18.0,
#   'Folate_Tot_pg': 18.0,
#   'Folate_rda': 0.012757500000000001,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 18.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': 0.64,
#   'Iron_rda': 0.01008,
#   'Lipid_Tot_g': 29.2,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': 22.0,
#   'Magnesium_rda': 0.015592500000000002,
#   'Manganese_mg': 0.021,
#   'Manganese_rda': 0.0029767500000000007,
#   'Molybdenum_rda': 1.4212800000000003,
#   'NDB_No': 1008,
#   'Niacin_mg': 0.18,
#   'Niacin_rda': 0.0025515,
#   'Panto_Acid_mg': 0.19,
#   'PantothenicAcid_rda': 0.005386500000000001,
#   'Phosphorus_mg': 490.0,
#   'Phosphorus_rda': 0.138915,
#   'Potassium_mg': 93.0,
#   'Potassium_rda': 0.007533000000000001,
#   'Protein_g': 25.18,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 262.0,
#   'Riboflavin_mg': 0.45,
#   'Riboflavin_rda': 0.07504411764705883,
#   'Satfat_rda': 0.26342820000000006,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,CARAWAY',
#   'Sodium_mg': 690.0,
#   'Sodium_rda': 0.08150625,
#   'Sugar_Tot_g': nan,
#   'Thiamin_mg': 0.031,
#   'Thiamin_rda': 0.0058590000000000005,
#   'Totfat_rda': 0.1273569230769231,
#   'Vit_A_IU': 1054.0,
#   'Vit_A_RAE': 271.0,
#   'Vit_B12_pg': 0.27,
#   'Vit_B6_mg': 0.074,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.059761800000000004,
#   'VitaminB12_rda': 0.012757500000000003,
#   'VitaminB6_rda': 0.0104895,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 39.28,
#   'Zinc_mg': 2.94,
#   'Zinc_rda': 0.05556600000000001,
#   'protein_rda': 0.14277060000000003},
#  8: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 3.71,
#   'Beta_Carot_pg': 85.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 710.0,
#   'Calcium_rda': 0.9372,
#   'Calories': 533.28,
#   'Calories_rda': 0.26664000000000004,
#   'Carbohydrt_g': 3.09,
#   'Cholestrl_mg': 99.0,
#   'Choline_Tot_ mg': 16.5,
#   'Colesterol_rda': 0.43560000000000004,
#   'Copper_mg': 0.03,
#   'Copper_rda': 0.0198,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 404,
#   'FA_Mono_g': 9.246,
#   'FA_Poly_g': 1.421,
#   'FA_Sat_g': 18.867,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 27.0,
#   'Folate_Tot_pg': 27.0,
#   'Folate_rda': 0.08910000000000001,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 27.0,
#   'GmWt_1': 132.0,
#   'GmWt_2': 244.0,
#   'GmWt_Desc1': '1 cup, diced',
#   'GmWt_Desc2': '1 cup, melted',
#   'Healthy': 9.88958931652661,
#   'Iron_mg': 0.14,
#   'Iron_rda': 0.010266666666666669,
#   'Lipid_Tot_g': 33.31,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 27.0,
#   'Magnesium_rda': 0.08910000000000001,
#   'Manganese_mg': 0.027,
#   'Manganese_rda': 0.01782,
#   'Molybdenum_rda': 7.1104,
#   'NDB_No': 1009,
#   'Niacin_mg': 0.059,
#   'Niacin_rda': 0.003894,
#   'Panto_Acid_mg': 0.41,
#   'PantothenicAcid_rda': 0.054119999999999994,
#   'Phosphorus_mg': 455.0,
#   'Phosphorus_rda': 0.6006,
#   'Potassium_mg': 76.0,
#   'Potassium_rda': 0.028662857142857143,
#   'Protein_g': 22.87,
#   'Quantity': '1 cup, diced',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 330.0,
#   'Riboflavin_mg': 0.428,
#   'Riboflavin_rda': 0.33232941176470593,
#   'Satfat_rda': 1.245222,
#   'Selenium_pg': 28.5,
#   'Selenium_rda': 0.5374285714285715,
#   'Shrt_Desc': 'CHEESE,CHEDDAR',
#   'Sodium_mg': 653.0,
#   'Sodium_rda': 0.35915,
#   'Sugar_Tot_g': 0.48,
#   'Thiamin_mg': 0.029,
#   'Thiamin_rda': 0.02552,
#   'Totfat_rda': 0.6764492307692309,
#   'Vit_A_IU': 1242.0,
#   'Vit_A_RAE': 330.0,
#   'Vit_B12_pg': 1.1,
#   'Vit_B6_mg': 0.066,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 24.0,
#   'Vit_D_pg': 0.6,
#   'Vit_E_mg': 0.71,
#   'Vit_K_pg': 2.4,
#   'VitaminA_rda': 0.327888,
#   'VitaminB12_rda': 0.24200000000000002,
#   'VitaminB6_rda': 0.04356,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00198,
#   'VitaminE_rda': 0.03124,
#   'VitaminK_rda': 0.0396,
#   'Water_g': 37.02,
#   'Zinc_mg': 3.64,
#   'Zinc_rda': 0.32032,
#   'protein_rda': 0.6037680000000001},
#  9: {'Alpha_Carot_pg': nan,
#   'Ash_g': 3.6,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 643.0,
#   'Calcium_rda': 0.18229050000000002,
#   'Calories': 109.71450000000002,
#   'Calories_rda': 0.05485725000000001,
#   'Carbohydrt_g': 4.78,
#   'Cholestrl_mg': 103.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.097335,
#   'Copper_mg': 0.042,
#   'Copper_rda': 0.005953500000000001,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 387,
#   'FA_Mono_g': 8.671,
#   'FA_Poly_g': 0.87,
#   'FA_Sat_g': 19.475,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 18.0,
#   'Folate_Tot_pg': 18.0,
#   'Folate_rda': 0.012757500000000001,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 18.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': 0.21,
#   'Iron_rda': 0.0033075,
#   'Lipid_Tot_g': 30.6,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': 21.0,
#   'Magnesium_rda': 0.014883750000000001,
#   'Manganese_mg': 0.012,
#   'Manganese_rda': 0.0017010000000000003,
#   'Molybdenum_rda': 1.4628600000000003,
#   'NDB_No': 1010,
#   'Niacin_mg': 0.08,
#   'Niacin_rda': 0.0011340000000000002,
#   'Panto_Acid_mg': 0.413,
#   'PantothenicAcid_rda': 0.01170855,
#   'Phosphorus_mg': 464.0,
#   'Phosphorus_rda': 0.13154400000000002,
#   'Potassium_mg': 95.0,
#   'Potassium_rda': 0.0076950000000000005,
#   'Protein_g': 23.37,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 220.0,
#   'Riboflavin_mg': 0.293,
#   'Riboflavin_rda': 0.04886205882352941,
#   'Satfat_rda': 0.27605812500000004,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,CHESHIRE',
#   'Sodium_mg': 700.0,
#   'Sodium_rda': 0.08268750000000001,
#   'Sugar_Tot_g': nan,
#   'Thiamin_mg': 0.046,
#   'Thiamin_rda': 0.008694,
#   'Totfat_rda': 0.13346307692307693,
#   'Vit_A_IU': 985.0,
#   'Vit_A_RAE': 233.0,
#   'Vit_B12_pg': 0.83,
#   'Vit_B6_mg': 0.074,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.05584950000000001,
#   'VitaminB12_rda': 0.0392175,
#   'VitaminB6_rda': 0.0104895,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 37.65,
#   'Zinc_mg': 2.79,
#   'Zinc_rda': 0.05273100000000001,
#   'protein_rda': 0.1325079},
#  10: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 3.36,
#   'Beta_Carot_pg': 82.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 685.0,
#   'Calcium_rda': 0.9042000000000001,
#   'Calories': 520.08,
#   'Calories_rda': 0.26004000000000005,
#   'Carbohydrt_g': 2.57,
#   'Cholestrl_mg': 95.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.418,
#   'Copper_mg': 0.042,
#   'Copper_rda': 0.02772,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 394,
#   'FA_Mono_g': 9.28,
#   'FA_Poly_g': 0.953,
#   'FA_Sat_g': 20.218,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 18.0,
#   'Folate_Tot_pg': 18.0,
#   'Folate_rda': 0.0594,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 18.0,
#   'GmWt_1': 132.0,
#   'GmWt_2': 113.0,
#   'GmWt_Desc1': '1 cup, diced',
#   'GmWt_Desc2': '1 cup, shredded',
#   'Healthy': 9.267005708683474,
#   'Iron_mg': 0.76,
#   'Iron_rda': 0.055733333333333336,
#   'Lipid_Tot_g': 32.11,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 26.0,
#   'Magnesium_rda': 0.0858,
#   'Manganese_mg': 0.012,
#   'Manganese_rda': 0.00792,
#   'Molybdenum_rda': 6.9344,
#   'NDB_No': 1011,
#   'Niacin_mg': 0.093,
#   'Niacin_rda': 0.006137999999999999,
#   'Panto_Acid_mg': 0.21,
#   'PantothenicAcid_rda': 0.027719999999999998,
#   'Phosphorus_mg': 457.0,
#   'Phosphorus_rda': 0.60324,
#   'Potassium_mg': 127.0,
#   'Potassium_rda': 0.04789714285714285,
#   'Protein_g': 23.76,
#   'Quantity': '1 cup, diced',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 257.0,
#   'Riboflavin_mg': 0.375,
#   'Riboflavin_rda': 0.2911764705882353,
#   'Satfat_rda': 1.334388,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.27342857142857147,
#   'Shrt_Desc': 'CHEESE,COLBY',
#   'Sodium_mg': 604.0,
#   'Sodium_rda': 0.3322,
#   'Sugar_Tot_g': 0.52,
#   'Thiamin_mg': 0.015,
#   'Thiamin_rda': 0.013200000000000002,
#   'Totfat_rda': 0.65208,
#   'Vit_A_IU': 994.0,
#   'Vit_A_RAE': 264.0,
#   'Vit_B12_pg': 0.83,
#   'Vit_B6_mg': 0.079,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 24.0,
#   'Vit_D_pg': 0.6,
#   'Vit_E_mg': 0.28,
#   'Vit_K_pg': 2.7,
#   'VitaminA_rda': 0.26241600000000004,
#   'VitaminB12_rda': 0.1826,
#   'VitaminB6_rda': 0.052140000000000006,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00198,
#   'VitaminE_rda': 0.012320000000000001,
#   'VitaminK_rda': 0.044550000000000006,
#   'Water_g': 38.2,
#   'Zinc_mg': 3.07,
#   'Zinc_rda': 0.27016,
#   'protein_rda': 0.627264},
#  11: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 1.41,
#   'Beta_Carot_pg': 12.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 83.0,
#   'Calcium_rda': 0.09379,
#   'Calories': 110.74,
#   'Calories_rda': 0.055369999999999996,
#   'Carbohydrt_g': 3.38,
#   'Cholestrl_mg': 17.0,
#   'Choline_Tot_ mg': 18.4,
#   'Colesterol_rda': 0.06403333333333332,
#   'Copper_mg': 0.029,
#   'Copper_rda': 0.016385,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 98,
#   'FA_Mono_g': 0.778,
#   'FA_Poly_g': 0.123,
#   'FA_Sat_g': 1.718,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 12.0,
#   'Folate_Tot_pg': 12.0,
#   'Folate_rda': 0.03389999999999999,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 12.0,
#   'GmWt_1': 113.0,
#   'GmWt_2': 210.0,
#   'GmWt_Desc1': '4 oz',
#   'GmWt_Desc2': '1 cup, large curd (not packed)',
#   'Healthy': 1.1958581619981328,
#   'Iron_mg': 0.07,
#   'Iron_rda': 0.004394444444444445,
#   'Lipid_Tot_g': 4.3,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 8.0,
#   'Magnesium_rda': 0.0226,
#   'Manganese_mg': 0.002,
#   'Manganese_rda': 0.00113,
#   'Molybdenum_rda': 1.4765333333333333,
#   'NDB_No': 1012,
#   'Niacin_mg': 0.099,
#   'Niacin_rda': 0.0055934999999999995,
#   'Panto_Acid_mg': 0.557,
#   'PantothenicAcid_rda': 0.062941,
#   'Phosphorus_mg': 159.0,
#   'Phosphorus_rda': 0.17967,
#   'Potassium_mg': 104.0,
#   'Potassium_rda': 0.033577142857142854,
#   'Protein_g': 11.12,
#   'Quantity': '4 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 36.0,
#   'Riboflavin_mg': 0.163,
#   'Riboflavin_rda': 0.10834705882352941,
#   'Satfat_rda': 0.097067,
#   'Selenium_pg': 9.7,
#   'Selenium_rda': 0.15658571428571427,
#   'Shrt_Desc': 'CHEESE,COTTAGE,CRMD,LRG OR SML CURD',
#   'Sodium_mg': 364.0,
#   'Sodium_rda': 0.17138333333333333,
#   'Sugar_Tot_g': 2.67,
#   'Thiamin_mg': 0.027,
#   'Thiamin_rda': 0.020339999999999997,
#   'Totfat_rda': 0.07475384615384614,
#   'Vit_A_IU': 140.0,
#   'Vit_A_RAE': 37.0,
#   'Vit_B12_pg': 0.43,
#   'Vit_B6_mg': 0.046,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 3.0,
#   'Vit_D_pg': 0.1,
#   'Vit_E_mg': 0.08,
#   'Vit_K_pg': 0.0,
#   'VitaminA_rda': 0.031639999999999995,
#   'VitaminB12_rda': 0.08098333333333332,
#   'VitaminB6_rda': 0.025989999999999996,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0002825,
#   'VitaminE_rda': 0.003013333333333333,
#   'VitaminK_rda': 0.0,
#   'Water_g': 79.79,
#   'Zinc_mg': 0.4,
#   'Zinc_rda': 0.03013333333333333,
#   'protein_rda': 0.251312},
#  12: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 1.2,
#   'Beta_Carot_pg': 14.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 53.0,
#   'Calcium_rda': 0.05988999999999999,
#   'Calories': 109.60999999999999,
#   'Calories_rda': 0.054805,
#   'Carbohydrt_g': 4.61,
#   'Cholestrl_mg': 13.0,
#   'Choline_Tot_ mg': 17.5,
#   'Colesterol_rda': 0.048966666666666665,
#   'Copper_mg': 0.04,
#   'Copper_rda': 0.0226,
#   'Dietfiber_rda': 0.00904,
#   'Energ_Kcal': 97,
#   'FA_Mono_g': 1.036,
#   'FA_Poly_g': 0.124,
#   'FA_Sat_g': 2.311,
#   'Fiber_TD_g': 0.2,
#   'Folate_DFE_pg': 11.0,
#   'Folate_Tot_pg': 11.0,
#   'Folate_rda': 0.031075,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 11.0,
#   'GmWt_1': 113.0,
#   'GmWt_2': 226.0,
#   'GmWt_Desc1': '4 oz',
#   'GmWt_Desc2': '1 cup,  (not packed)',
#   'Healthy': 1.1979211241830061,
#   'Iron_mg': 0.16,
#   'Iron_rda': 0.010044444444444443,
#   'Lipid_Tot_g': 3.85,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 7.0,
#   'Magnesium_rda': 0.019775,
#   'Manganese_mg': 0.003,
#   'Manganese_rda': 0.001695,
#   'Molybdenum_rda': 1.4614666666666665,
#   'NDB_No': 1013,
#   'Niacin_mg': 0.15,
#   'Niacin_rda': 0.008474999999999998,
#   'Panto_Acid_mg': 0.181,
#   'PantothenicAcid_rda': 0.020452999999999995,
#   'Phosphorus_mg': 113.0,
#   'Phosphorus_rda': 0.12769,
#   'Potassium_mg': 90.0,
#   'Potassium_rda': 0.029057142857142854,
#   'Protein_g': 10.69,
#   'Quantity': '4 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 37.0,
#   'Riboflavin_mg': 0.142,
#   'Riboflavin_rda': 0.09438823529411763,
#   'Satfat_rda': 0.13057149999999998,
#   'Selenium_pg': 7.7,
#   'Selenium_rda': 0.1243,
#   'Shrt_Desc': 'CHEESE,COTTAGE,CRMD,W/FRUIT',
#   'Sodium_mg': 344.0,
#   'Sodium_rda': 0.16196666666666665,
#   'Sugar_Tot_g': 2.38,
#   'Thiamin_mg': 0.033,
#   'Thiamin_rda': 0.02486,
#   'Totfat_rda': 0.06693076923076922,
#   'Vit_A_IU': 146.0,
#   'Vit_A_RAE': 38.0,
#   'Vit_B12_pg': 0.53,
#   'Vit_B6_mg': 0.068,
#   'Vit_C_mg': 1.4,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 0.04,
#   'Vit_K_pg': 0.4,
#   'VitaminA_rda': 0.032996,
#   'VitaminB12_rda': 0.09981666666666665,
#   'VitaminB6_rda': 0.038419999999999996,
#   'VitaminC_rda': 0.02636666666666666,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.0015066666666666666,
#   'VitaminK_rda': 0.00565,
#   'Water_g': 79.64,
#   'Zinc_mg': 0.33,
#   'Zinc_rda': 0.02486,
#   'protein_rda': 0.24159399999999998},
#  13: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 1.71,
#   'Beta_Carot_pg': 0.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 86.0,
#   'Calcium_rda': 0.12469999999999999,
#   'Calories': 104.39999999999999,
#   'Calories_rda': 0.052199999999999996,
#   'Carbohydrt_g': 6.66,
#   'Cholestrl_mg': 7.0,
#   'Choline_Tot_ mg': 17.9,
#   'Colesterol_rda': 0.03383333333333333,
#   'Copper_mg': 0.03,
#   'Copper_rda': 0.02175,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 72,
#   'FA_Mono_g': 0.079,
#   'FA_Poly_g': 0.003,
#   'FA_Sat_g': 0.169,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 9.0,
#   'Folate_Tot_pg': 9.0,
#   'Folate_rda': 0.032625,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 9.0,
#   'GmWt_1': 145.0,
#   'GmWt_2': 113.0,
#   'GmWt_Desc1': '1 cup,  (not packed)',
#   'GmWt_Desc2': '4 oz',
#   'Healthy': 0.9630806582633054,
#   'Iron_mg': 0.15,
#   'Iron_rda': 0.012083333333333333,
#   'Lipid_Tot_g': 0.29,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 11.0,
#   'Magnesium_rda': 0.039875,
#   'Manganese_mg': 0.022,
#   'Manganese_rda': 0.01595,
#   'Molybdenum_rda': 1.392,
#   'NDB_No': 1014,
#   'Niacin_mg': 0.144,
#   'Niacin_rda': 0.01044,
#   'Panto_Acid_mg': 0.446,
#   'PantothenicAcid_rda': 0.06467,
#   'Phosphorus_mg': 190.0,
#   'Phosphorus_rda': 0.27549999999999997,
#   'Potassium_mg': 137.0,
#   'Potassium_rda': 0.05675714285714286,
#   'Protein_g': 10.34,
#   'Quantity': '1 cup,  (not packed)',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 2.0,
#   'Riboflavin_mg': 0.226,
#   'Riboflavin_rda': 0.19276470588235292,
#   'Satfat_rda': 0.012252500000000001,
#   'Selenium_pg': 9.4,
#   'Selenium_rda': 0.1947142857142857,
#   'Shrt_Desc': 'CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD',
#   'Sodium_mg': 372.0,
#   'Sodium_rda': 0.22475,
#   'Sugar_Tot_g': 1.85,
#   'Thiamin_mg': 0.023,
#   'Thiamin_rda': 0.02223333333333333,
#   'Totfat_rda': 0.006469230769230769,
#   'Vit_A_IU': 8.0,
#   'Vit_A_RAE': 2.0,
#   'Vit_B12_pg': 0.46,
#   'Vit_B6_mg': 0.016,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 0.01,
#   'Vit_K_pg': 0.0,
#   'VitaminA_rda': 0.00232,
#   'VitaminB12_rda': 0.11116666666666668,
#   'VitaminB6_rda': 0.0116,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.0004833333333333333,
#   'VitaminK_rda': 0.0,
#   'Water_g': 81.01,
#   'Zinc_mg': 0.47,
#   'Zinc_rda': 0.045433333333333326,
#   'protein_rda': 0.29985999999999996},
#  14: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 1.27,
#   'Beta_Carot_pg': 6.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 111.0,
#   'Calcium_rda': 0.12542999999999999,
#   'Calories': 91.52999999999999,
#   'Calories_rda': 0.045765,
#   'Carbohydrt_g': 4.76,
#   'Cholestrl_mg': 12.0,
#   'Choline_Tot_ mg': 16.3,
#   'Colesterol_rda': 0.0452,
#   'Copper_mg': 0.033,
#   'Copper_rda': 0.018645,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 81,
#   'FA_Mono_g': 0.516,
#   'FA_Poly_g': 0.083,
#   'FA_Sat_g': 1.235,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 8.0,
#   'Folate_Tot_pg': 8.0,
#   'Folate_rda': 0.0226,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 8.0,
#   'GmWt_1': 113.0,
#   'GmWt_2': 226.0,
#   'GmWt_Desc1': '4 oz',
#   'GmWt_Desc2': '1 cup,  (not packed)',
#   'Healthy': 1.40587989869281,
#   'Iron_mg': 0.13,
#   'Iron_rda': 0.00816111111111111,
#   'Lipid_Tot_g': 2.27,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 9.0,
#   'Magnesium_rda': 0.025424999999999996,
#   'Manganese_mg': 0.015,
#   'Manganese_rda': 0.008474999999999998,
#   'Molybdenum_rda': 1.2204,
#   'NDB_No': 1015,
#   'Niacin_mg': 0.103,
#   'Niacin_rda': 0.005819499999999999,
#   'Panto_Acid_mg': 0.524,
#   'PantothenicAcid_rda': 0.059211999999999994,
#   'Phosphorus_mg': 150.0,
#   'Phosphorus_rda': 0.16949999999999998,
#   'Potassium_mg': 125.0,
#   'Potassium_rda': 0.04035714285714285,
#   'Protein_g': 10.45,
#   'Quantity': '4 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 68.0,
#   'Riboflavin_mg': 0.251,
#   'Riboflavin_rda': 0.16684117647058821,
#   'Satfat_rda': 0.0697775,
#   'Selenium_pg': 11.9,
#   'Selenium_rda': 0.1921,
#   'Shrt_Desc': 'CHEESE,COTTAGE,LOWFAT,2% MILKFAT',
#   'Sodium_mg': 308.0,
#   'Sodium_rda': 0.14501666666666665,
#   'Sugar_Tot_g': 4.0,
#   'Thiamin_mg': 0.02,
#   'Thiamin_rda': 0.015066666666666666,
#   'Totfat_rda': 0.03946307692307692,
#   'Vit_A_IU': 225.0,
#   'Vit_A_RAE': 68.0,
#   'Vit_B12_pg': 0.47,
#   'Vit_B6_mg': 0.057,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 0.08,
#   'Vit_K_pg': 0.0,
#   'VitaminA_rda': 0.05084999999999999,
#   'VitaminB12_rda': 0.08851666666666665,
#   'VitaminB6_rda': 0.032205,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.003013333333333333,
#   'VitaminK_rda': 0.0,
#   'Water_g': 81.24,
#   'Zinc_mg': 0.51,
#   'Zinc_rda': 0.038419999999999996,
#   'protein_rda': 0.23616999999999996},
#  15: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 1.39,
#   'Beta_Carot_pg': 3.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 61.0,
#   'Calcium_rda': 0.06892999999999999,
#   'Calories': 81.35999999999999,
#   'Calories_rda': 0.040679999999999994,
#   'Carbohydrt_g': 2.72,
#   'Cholestrl_mg': 4.0,
#   'Choline_Tot_ mg': 17.5,
#   'Colesterol_rda': 0.015066666666666666,
#   'Copper_mg': 0.028,
#   'Copper_rda': 0.015819999999999997,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 72,
#   'FA_Mono_g': 0.291,
#   'FA_Poly_g': 0.031,
#   'FA_Sat_g': 0.645,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 12.0,
#   'Folate_Tot_pg': 12.0,
#   'Folate_rda': 0.03389999999999999,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 12.0,
#   'GmWt_1': 113.0,
#   'GmWt_2': 226.0,
#   'GmWt_Desc1': '4 oz',
#   'GmWt_Desc2': '1 cup,  (not packed)',
#   'Healthy': 0.5553412959850603,
#   'Iron_mg': 0.14,
#   'Iron_rda': 0.00878888888888889,
#   'Lipid_Tot_g': 1.02,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 5.0,
#   'Magnesium_rda': 0.014124999999999999,
#   'Manganese_mg': 0.003,
#   'Manganese_rda': 0.001695,
#   'Molybdenum_rda': 1.0847999999999998,
#   'NDB_No': 1016,
#   'Niacin_mg': 0.128,
#   'Niacin_rda': 0.007232,
#   'Panto_Acid_mg': 0.215,
#   'PantothenicAcid_rda': 0.024294999999999997,
#   'Phosphorus_mg': 134.0,
#   'Phosphorus_rda': 0.15142,
#   'Potassium_mg': 86.0,
#   'Potassium_rda': 0.027765714285714282,
#   'Protein_g': 12.39,
#   'Quantity': '4 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 11.0,
#   'Riboflavin_mg': 0.165,
#   'Riboflavin_rda': 0.10967647058823529,
#   'Satfat_rda': 0.036442499999999996,
#   'Selenium_pg': 9.0,
#   'Selenium_rda': 0.14528571428571427,
#   'Shrt_Desc': 'CHEESE,COTTAGE,LOWFAT,1% MILKFAT',
#   'Sodium_mg': 406.0,
#   'Sodium_rda': 0.19115833333333332,
#   'Sugar_Tot_g': 2.72,
#   'Thiamin_mg': 0.021,
#   'Thiamin_rda': 0.015819999999999997,
#   'Totfat_rda': 0.01773230769230769,
#   'Vit_A_IU': 41.0,
#   'Vit_A_RAE': 11.0,
#   'Vit_B12_pg': 0.63,
#   'Vit_B6_mg': 0.068,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 0.01,
#   'Vit_K_pg': 0.1,
#   'VitaminA_rda': 0.009266,
#   'VitaminB12_rda': 0.11864999999999998,
#   'VitaminB6_rda': 0.038419999999999996,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.00037666666666666664,
#   'VitaminK_rda': 0.0014125,
#   'Water_g': 82.48,
#   'Zinc_mg': 0.38,
#   'Zinc_rda': 0.028626666666666665,
#   'protein_rda': 0.280014},
#  16: {'Alpha_Carot_pg': 1.0,
#   'Ash_g': 1.27,
#   'Beta_Carot_pg': 59.0,
#   'Beta_Crypt_pg': 2.0,
#   'Calcium_mg': 97.0,
#   'Calcium_rda': 0.014065,
#   'Calories': 50.75,
#   'Calories_rda': 0.025374999999999998,
#   'Carbohydrt_g': 5.52,
#   'Cholestrl_mg': 101.0,
#   'Choline_Tot_ mg': 27.2,
#   'Colesterol_rda': 0.04881666666666666,
#   'Copper_mg': 0.018,
#   'Copper_rda': 0.0013049999999999997,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 350,
#   'FA_Mono_g': 8.907,
#   'FA_Poly_g': 1.483,
#   'FA_Sat_g': 20.213,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 9.0,
#   'Folate_Tot_pg': 9.0,
#   'Folate_rda': 0.0032624999999999998,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 9.0,
#   'GmWt_1': 14.5,
#   'GmWt_2': 232.0,
#   'GmWt_Desc1': '1 tbsp',
#   'GmWt_Desc2': '1 cup',
#   'Healthy': 0.7186959049953314,
#   'Iron_mg': 0.11,
#   'Iron_rda': 0.0008861111111111111,
#   'Lipid_Tot_g': 34.44,
#   'Lut+Zea_ pg': 7.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 9.0,
#   'Magnesium_rda': 0.0032624999999999998,
#   'Manganese_mg': 0.011,
#   'Manganese_rda': 0.0007974999999999999,
#   'Molybdenum_rda': 0.6766666666666666,
#   'NDB_No': 1017,
#   'Niacin_mg': 0.091,
#   'Niacin_rda': 0.00065975,
#   'Panto_Acid_mg': 0.517,
#   'PantothenicAcid_rda': 0.0074965,
#   'Phosphorus_mg': 107.0,
#   'Phosphorus_rda': 0.015515,
#   'Potassium_mg': 132.0,
#   'Potassium_rda': 0.0054685714285714285,
#   'Protein_g': 6.15,
#   'Quantity': '1 tbsp',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 303.0,
#   'Riboflavin_mg': 0.23,
#   'Riboflavin_rda': 0.01961764705882353,
#   'Satfat_rda': 0.14654425,
#   'Selenium_pg': 8.6,
#   'Selenium_rda': 0.017814285714285713,
#   'Shrt_Desc': 'CHEESE,CREAM',
#   'Sodium_mg': 314.0,
#   'Sodium_rda': 0.018970833333333333,
#   'Sugar_Tot_g': 3.76,
#   'Thiamin_mg': 0.023,
#   'Thiamin_rda': 0.0022233333333333332,
#   'Totfat_rda': 0.0768276923076923,
#   'Vit_A_IU': 1111.0,
#   'Vit_A_RAE': 308.0,
#   'Vit_B12_pg': 0.22,
#   'Vit_B6_mg': 0.056,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 0.0,
#   'Vit_D_pg': 0.0,
#   'Vit_E_mg': 0.86,
#   'Vit_K_pg': 2.1,
#   'VitaminA_rda': 0.032219,
#   'VitaminB12_rda': 0.005316666666666667,
#   'VitaminB6_rda': 0.004059999999999999,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0,
#   'VitaminE_rda': 0.004156666666666666,
#   'VitaminK_rda': 0.00380625,
#   'Water_g': 52.62,
#   'Zinc_mg': 0.5,
#   'Zinc_rda': 0.004833333333333333,
#   'protein_rda': 0.017835},
#  17: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 4.22,
#   'Beta_Carot_pg': 11.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 731.0,
#   'Calcium_rda': 0.20723850000000002,
#   'Calories': 101.2095,
#   'Calories_rda': 0.050604750000000004,
#   'Carbohydrt_g': 1.43,
#   'Cholestrl_mg': 89.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.08410500000000001,
#   'Copper_mg': 0.036,
#   'Copper_rda': 0.005103,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 357,
#   'FA_Mono_g': 8.125,
#   'FA_Poly_g': 0.665,
#   'FA_Sat_g': 17.572,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 16.0,
#   'Folate_Tot_pg': 16.0,
#   'Folate_rda': 0.011340000000000001,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 16.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': 198.0,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': '1 package,  (7 oz)',
#   'Healthy': 1.7265212205882356,
#   'Iron_mg': 0.44,
#   'Iron_rda': 0.006930000000000001,
#   'Lipid_Tot_g': 27.8,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 30.0,
#   'Magnesium_rda': 0.0212625,
#   'Manganese_mg': 0.011,
#   'Manganese_rda': 0.00155925,
#   'Molybdenum_rda': 1.34946,
#   'NDB_No': 1018,
#   'Niacin_mg': 0.082,
#   'Niacin_rda': 0.0011623500000000001,
#   'Panto_Acid_mg': 0.281,
#   'PantothenicAcid_rda': 0.007966350000000002,
#   'Phosphorus_mg': 536.0,
#   'Phosphorus_rda': 0.15195600000000004,
#   'Potassium_mg': 188.0,
#   'Potassium_rda': 0.015228000000000002,
#   'Protein_g': 24.99,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 242.0,
#   'Riboflavin_mg': 0.389,
#   'Riboflavin_rda': 0.06487147058823531,
#   'Satfat_rda': 0.2490831,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,EDAM',
#   'Sodium_mg': 812.0,
#   'Sodium_rda': 0.0959175,
#   'Sugar_Tot_g': 1.43,
#   'Thiamin_mg': 0.037,
#   'Thiamin_rda': 0.006993000000000001,
#   'Totfat_rda': 0.12125076923076925,
#   'Vit_A_IU': 825.0,
#   'Vit_A_RAE': 243.0,
#   'Vit_B12_pg': 1.54,
#   'Vit_B6_mg': 0.076,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 20.0,
#   'Vit_D_pg': 0.5,
#   'Vit_E_mg': 0.24,
#   'Vit_K_pg': 2.3,
#   'VitaminA_rda': 0.04677750000000001,
#   'VitaminB12_rda': 0.07276500000000001,
#   'VitaminB6_rda': 0.010773000000000001,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00035437500000000004,
#   'VitaminE_rda': 0.0022680000000000005,
#   'VitaminK_rda': 0.008150625,
#   'Water_g': 41.56,
#   'Zinc_mg': 3.75,
#   'Zinc_rda': 0.07087500000000001,
#   'protein_rda': 0.1416933},
#  18: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 5.2,
#   'Beta_Carot_pg': 3.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 493.0,
#   'Calcium_rda': 0.7395,
#   'Calories': 396.0,
#   'Calories_rda': 0.198,
#   'Carbohydrt_g': 4.09,
#   'Cholestrl_mg': 89.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.44500000000000006,
#   'Copper_mg': 0.032,
#   'Copper_rda': 0.024,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 264,
#   'FA_Mono_g': 4.623,
#   'FA_Poly_g': 0.591,
#   'FA_Sat_g': 14.946,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 32.0,
#   'Folate_Tot_pg': 32.0,
#   'Folate_rda': 0.12,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 32.0,
#   'GmWt_1': 150.0,
#   'GmWt_2': 28.35,
#   'GmWt_Desc1': '1 cup, crumbled',
#   'GmWt_Desc2': '1 oz',
#   'Healthy': 6.262342787114846,
#   'Iron_mg': 0.65,
#   'Iron_rda': 0.05416666666666667,
#   'Lipid_Tot_g': 21.28,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 19.0,
#   'Magnesium_rda': 0.07125000000000001,
#   'Manganese_mg': 0.028,
#   'Manganese_rda': 0.021,
#   'Molybdenum_rda': 5.28,
#   'NDB_No': 1019,
#   'Niacin_mg': 0.991,
#   'Niacin_rda': 0.074325,
#   'Panto_Acid_mg': 0.967,
#   'PantothenicAcid_rda': 0.14504999999999998,
#   'Phosphorus_mg': 337.0,
#   'Phosphorus_rda': 0.5055000000000001,
#   'Potassium_mg': 62.0,
#   'Potassium_rda': 0.026571428571428572,
#   'Protein_g': 14.21,
#   'Quantity': '1 cup, crumbled',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 125.0,
#   'Riboflavin_mg': 0.844,
#   'Riboflavin_rda': 0.7447058823529411,
#   'Satfat_rda': 1.12095,
#   'Selenium_pg': 15.0,
#   'Selenium_rda': 0.3214285714285714,
#   'Shrt_Desc': 'CHEESE,FETA',
#   'Sodium_mg': 917.0,
#   'Sodium_rda': 0.573125,
#   'Sugar_Tot_g': 4.09,
#   'Thiamin_mg': 0.154,
#   'Thiamin_rda': 0.154,
#   'Totfat_rda': 0.4910769230769231,
#   'Vit_A_IU': 422.0,
#   'Vit_A_RAE': 125.0,
#   'Vit_B12_pg': 1.69,
#   'Vit_B6_mg': 0.424,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 16.0,
#   'Vit_D_pg': 0.4,
#   'Vit_E_mg': 0.18,
#   'Vit_K_pg': 1.8,
#   'VitaminA_rda': 0.1266,
#   'VitaminB12_rda': 0.4225,
#   'VitaminB6_rda': 0.318,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.0015,
#   'VitaminE_rda': 0.009000000000000001,
#   'VitaminK_rda': 0.03375,
#   'Water_g': 55.22,
#   'Zinc_mg': 2.88,
#   'Zinc_rda': 0.28800000000000003,
#   'protein_rda': 0.4263},
#  19: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 3.79,
#   'Beta_Carot_pg': 32.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 550.0,
#   'Calcium_rda': 0.7260000000000001,
#   'Calories': 513.48,
#   'Calories_rda': 0.25674,
#   'Carbohydrt_g': 1.55,
#   'Cholestrl_mg': 116.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.5104,
#   'Copper_mg': 0.025,
#   'Copper_rda': 0.0165,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 389,
#   'FA_Mono_g': 8.687,
#   'FA_Poly_g': 1.654,
#   'FA_Sat_g': 19.196,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 6.0,
#   'Folate_Tot_pg': 6.0,
#   'Folate_rda': 0.0198,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 6.0,
#   'GmWt_1': 132.0,
#   'GmWt_2': 108.0,
#   'GmWt_Desc1': '1 cup, diced',
#   'GmWt_Desc2': '1 cup, shredded',
#   'Healthy': 7.753413904761905,
#   'Iron_mg': 0.23,
#   'Iron_rda': 0.01686666666666667,
#   'Lipid_Tot_g': 31.14,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 14.0,
#   'Magnesium_rda': 0.046200000000000005,
#   'Manganese_mg': 0.014,
#   'Manganese_rda': 0.00924,
#   'Molybdenum_rda': 6.8464,
#   'NDB_No': 1020,
#   'Niacin_mg': 0.15,
#   'Niacin_rda': 0.0099,
#   'Panto_Acid_mg': 0.429,
#   'PantothenicAcid_rda': 0.056628000000000005,
#   'Phosphorus_mg': 346.0,
#   'Phosphorus_rda': 0.45672,
#   'Potassium_mg': 64.0,
#   'Potassium_rda': 0.02413714285714286,
#   'Protein_g': 25.6,
#   'Quantity': '1 cup, diced',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 258.0,
#   'Riboflavin_mg': 0.204,
#   'Riboflavin_rda': 0.1584,
#   'Satfat_rda': 1.2669360000000003,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.27342857142857147,
#   'Shrt_Desc': 'CHEESE,FONTINA',
#   'Sodium_mg': 800.0,
#   'Sodium_rda': 0.44,
#   'Sugar_Tot_g': 1.55,
#   'Thiamin_mg': 0.021,
#   'Thiamin_rda': 0.01848,
#   'Totfat_rda': 0.6323815384615384,
#   'Vit_A_IU': 913.0,
#   'Vit_A_RAE': 261.0,
#   'Vit_B12_pg': 1.68,
#   'Vit_B6_mg': 0.083,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 23.0,
#   'Vit_D_pg': 0.6,
#   'Vit_E_mg': 0.27,
#   'Vit_K_pg': 2.6,
#   'VitaminA_rda': 0.24103200000000002,
#   'VitaminB12_rda': 0.3696,
#   'VitaminB6_rda': 0.05478,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00198,
#   'VitaminE_rda': 0.011880000000000002,
#   'VitaminK_rda': 0.0429,
#   'Water_g': 37.92,
#   'Zinc_mg': 3.5,
#   'Zinc_rda': 0.308,
#   'protein_rda': 0.67584},
#  20: {'Alpha_Carot_pg': nan,
#   'Ash_g': 4.75,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 400.0,
#   'Calcium_rda': 0.11340000000000001,
#   'Calories': 132.11100000000002,
#   'Calories_rda': 0.06605550000000002,
#   'Carbohydrt_g': 42.65,
#   'Cholestrl_mg': 94.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.08883000000000002,
#   'Copper_mg': 0.08,
#   'Copper_rda': 0.011340000000000001,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 466,
#   'FA_Mono_g': 7.879,
#   'FA_Poly_g': 0.938,
#   'FA_Sat_g': 19.16,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 5.0,
#   'Folate_Tot_pg': 5.0,
#   'Folate_rda': 0.0035437500000000005,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 5.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': 227.0,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': '1 package,  (8 oz)',
#   'Healthy': nan,
#   'Iron_mg': 0.52,
#   'Iron_rda': 0.008190000000000001,
#   'Lipid_Tot_g': 29.51,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': 70.0,
#   'Magnesium_rda': 0.049612500000000004,
#   'Manganese_mg': 0.04,
#   'Manganese_rda': 0.0056700000000000006,
#   'Molybdenum_rda': 1.7614800000000002,
#   'NDB_No': 1021,
#   'Niacin_mg': 0.813,
#   'Niacin_rda': 0.011524275,
#   'Panto_Acid_mg': 3.351,
#   'PantothenicAcid_rda': 0.09500085000000001,
#   'Phosphorus_mg': 444.0,
#   'Phosphorus_rda': 0.125874,
#   'Potassium_mg': 1409.0,
#   'Potassium_rda': 0.11412900000000001,
#   'Protein_g': 9.65,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 334.0,
#   'Riboflavin_mg': 1.382,
#   'Riboflavin_rda': 0.23046882352941178,
#   'Satfat_rda': 0.27159300000000003,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,GJETOST',
#   'Sodium_mg': 600.0,
#   'Sodium_rda': 0.07087500000000001,
#   'Sugar_Tot_g': nan,
#   'Thiamin_mg': 0.315,
#   'Thiamin_rda': 0.059535000000000005,
#   'Totfat_rda': 0.12870900000000002,
#   'Vit_A_IU': 1113.0,
#   'Vit_A_RAE': 334.0,
#   'Vit_B12_pg': 2.42,
#   'Vit_B6_mg': 0.271,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.0631071,
#   'VitaminB12_rda': 0.114345,
#   'VitaminB6_rda': 0.038414250000000004,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 13.44,
#   'Zinc_mg': 1.14,
#   'Zinc_rda': 0.021546000000000003,
#   'protein_rda': 0.05471550000000001},
#  21: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 3.94,
#   'Beta_Carot_pg': 10.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 700.0,
#   'Calcium_rda': 0.19845000000000002,
#   'Calories': 100.92600000000002,
#   'Calories_rda': 0.050463,
#   'Carbohydrt_g': 2.22,
#   'Cholestrl_mg': 114.0,
#   'Choline_Tot_ mg': 15.4,
#   'Colesterol_rda': 0.10773,
#   'Copper_mg': 0.036,
#   'Copper_rda': 0.005103,
#   'Dietfiber_rda': 0.0,
#   'Energ_Kcal': 356,
#   'FA_Mono_g': 7.747,
#   'FA_Poly_g': 0.657,
#   'FA_Sat_g': 17.614,
#   'Fiber_TD_g': 0.0,
#   'Folate_DFE_pg': 21.0,
#   'Folate_Tot_pg': 21.0,
#   'Folate_rda': 0.014883750000000001,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 21.0,
#   'GmWt_1': 28.35,
#   'GmWt_2': 198.0,
#   'GmWt_Desc1': '1 oz',
#   'GmWt_Desc2': '1 package,  (7 oz)',
#   'Healthy': 1.6675271867647061,
#   'Iron_mg': 0.24,
#   'Iron_rda': 0.00378,
#   'Lipid_Tot_g': 27.44,
#   'Lut+Zea_ pg': 0.0,
#   'Lycopene_pg': 0.0,
#   'Magnesium_mg': 29.0,
#   'Magnesium_rda': 0.02055375,
#   'Manganese_mg': 0.011,
#   'Manganese_rda': 0.00155925,
#   'Molybdenum_rda': 1.3456800000000002,
#   'NDB_No': 1022,
#   'Niacin_mg': 0.063,
#   'Niacin_rda': 0.0008930250000000001,
#   'Panto_Acid_mg': 0.34,
#   'PantothenicAcid_rda': 0.009639000000000002,
#   'Phosphorus_mg': 546.0,
#   'Phosphorus_rda': 0.15479100000000004,
#   'Potassium_mg': 121.0,
#   'Potassium_rda': 0.009801,
#   'Protein_g': 24.94,
#   'Quantity': '1 oz',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 164.0,
#   'Riboflavin_mg': 0.334,
#   'Riboflavin_rda': 0.05569941176470589,
#   'Satfat_rda': 0.24967845000000002,
#   'Selenium_pg': 14.5,
#   'Selenium_rda': 0.05872500000000001,
#   'Shrt_Desc': 'CHEESE,GOUDA',
#   'Sodium_mg': 819.0,
#   'Sodium_rda': 0.09674437500000001,
#   'Sugar_Tot_g': 2.22,
#   'Thiamin_mg': 0.03,
#   'Thiamin_rda': 0.0056700000000000006,
#   'Totfat_rda': 0.1196806153846154,
#   'Vit_A_IU': 563.0,
#   'Vit_A_RAE': 165.0,
#   'Vit_B12_pg': 1.54,
#   'Vit_B6_mg': 0.08,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': 20.0,
#   'Vit_D_pg': 0.5,
#   'Vit_E_mg': 0.24,
#   'Vit_K_pg': 2.3,
#   'VitaminA_rda': 0.0319221,
#   'VitaminB12_rda': 0.07276500000000001,
#   'VitaminB6_rda': 0.011340000000000001,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': 0.00035437500000000004,
#   'VitaminE_rda': 0.0022680000000000005,
#   'VitaminK_rda': 0.008150625,
#   'Water_g': 41.46,
#   'Zinc_mg': 3.9,
#   'Zinc_rda': 0.07371000000000001,
#   'protein_rda': 0.14140980000000003},
#  22: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 4.3,
#   'Beta_Carot_pg': 33.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 1011.0,
#   'Calcium_rda': 0.2866185,
#   'Calories': 117.08550000000001,
# ...
#   'Iron_rda': 0.0203,
#   'Lipid_Tot_g': 1.59,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': nan,
#   'Magnesium_rda': nan,
#   'Manganese_mg': nan,
#   'Manganese_rda': nan,
#   'Molybdenum_rda': 1.4616,
#   'NDB_No': 6351,
#   'Niacin_mg': nan,
#   'Niacin_rda': nan,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': nan,
#   'Phosphorus_rda': nan,
#   'Potassium_mg': 119.0,
#   'Potassium_rda': 0.04284,
#   'Protein_g': 0.79,
#   'Quantity': '1 serving, 1/2 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': nan,
#   'Riboflavin_mg': nan,
#   'Riboflavin_rda': nan,
#   'Satfat_rda': 0.025011,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': "CAMPBELL'S RED & WHITE,OLD FASHIONED TOMATO RICE SOUP,COND",
#   'Sodium_mg': 611.0,
#   'Sodium_rda': 0.320775,
#   'Sugar_Tot_g': 7.94,
#   'Thiamin_mg': nan,
#   'Thiamin_rda': nan,
#   'Totfat_rda': 0.030821538461538463,
#   'Vit_A_IU': 397.0,
#   'Vit_A_RAE': nan,
#   'Vit_B12_pg': nan,
#   'Vit_B6_mg': nan,
#   'Vit_C_mg': 1.9,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.100044,
#   'VitaminB12_rda': nan,
#   'VitaminB6_rda': nan,
#   'VitaminC_rda': 0.0399,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 74.5,
#   'Zinc_mg': nan,
#   'Zinc_rda': nan,
#   'protein_rda': 0.019908000000000002},
#  1404: {'Alpha_Carot_pg': nan,
#   'Ash_g': 2.76,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 65.0,
#   'Calcium_rda': 0.0806,
#   'Calories': 120.28,
#   'Calories_rda': 0.06014,
#   'Carbohydrt_g': 8.06,
#   'Cholestrl_mg': 8.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.03306666666666667,
#   'Copper_mg': nan,
#   'Copper_rda': nan,
#   'Dietfiber_rda': 0.03968,
#   'Energ_Kcal': 97,
#   'FA_Mono_g': 1.613,
#   'FA_Poly_g': 1.613,
#   'FA_Sat_g': 2.419,
#   'Fiber_TD_g': 0.8,
#   'Folate_DFE_pg': nan,
#   'Folate_Tot_pg': nan,
#   'Folate_rda': nan,
#   'Folic_Acid_pg': nan,
#   'Food_Folate_pg': nan,
#   'GmWt_1': 124.0,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 serving, 1/2 cup',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': 0.0,
#   'Iron_rda': 0.0,
#   'Lipid_Tot_g': 6.45,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': nan,
#   'Magnesium_rda': nan,
#   'Manganese_mg': nan,
#   'Manganese_rda': nan,
#   'Molybdenum_rda': 1.6037333333333332,
#   'NDB_No': 6353,
#   'Niacin_mg': nan,
#   'Niacin_rda': nan,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': nan,
#   'Phosphorus_rda': nan,
#   'Potassium_mg': 81.0,
#   'Potassium_rda': 0.028697142857142855,
#   'Protein_g': 2.42,
#   'Quantity': '1 serving, 1/2 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': nan,
#   'Riboflavin_mg': nan,
#   'Riboflavin_rda': nan,
#   'Satfat_rda': 0.149978,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': "CAMPBELL'S RED & WHITE,FIESTA NACHO CHS SOUP,COND",
#   'Sodium_mg': 637.0,
#   'Sodium_rda': 0.32911666666666667,
#   'Sugar_Tot_g': 1.61,
#   'Thiamin_mg': nan,
#   'Thiamin_rda': nan,
#   'Totfat_rda': 0.12304615384615385,
#   'Vit_A_IU': 403.0,
#   'Vit_A_RAE': nan,
#   'Vit_B12_pg': nan,
#   'Vit_B6_mg': nan,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.099944,
#   'VitaminB12_rda': nan,
#   'VitaminB6_rda': nan,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 80.3,
#   'Zinc_mg': nan,
#   'Zinc_rda': nan,
#   'protein_rda': 0.060016},
#  1405: {'Alpha_Carot_pg': nan,
#   'Ash_g': 1.46,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 16.0,
#   'Calcium_rda': 0.02016,
#   'Calories': 45.36,
#   'Calories_rda': 0.02268,
#   'Carbohydrt_g': 4.76,
#   'Cholestrl_mg': 4.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.016800000000000002,
#   'Copper_mg': nan,
#   'Copper_rda': nan,
#   'Dietfiber_rda': 0.04032,
#   'Energ_Kcal': 36,
#   'FA_Mono_g': 0.0,
#   'FA_Poly_g': 0.397,
#   'FA_Sat_g': 0.794,
#   'Fiber_TD_g': 0.8,
#   'Folate_DFE_pg': nan,
#   'Folate_Tot_pg': nan,
#   'Folate_rda': nan,
#   'Folic_Acid_pg': nan,
#   'Food_Folate_pg': nan,
#   'GmWt_1': 126.0,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 serving, 1/2 cup',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': 0.0,
#   'Iron_rda': 0.0,
#   'Lipid_Tot_g': 1.19,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': nan,
#   'Magnesium_rda': nan,
#   'Manganese_mg': nan,
#   'Manganese_rda': nan,
#   'Molybdenum_rda': 0.6048,
#   'NDB_No': 6354,
#   'Niacin_mg': nan,
#   'Niacin_rda': nan,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': nan,
#   'Phosphorus_rda': nan,
#   'Potassium_mg': 444.0,
#   'Potassium_rda': 0.15984,
#   'Protein_g': 1.59,
#   'Quantity': '1 serving, 1/2 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': nan,
#   'Riboflavin_mg': nan,
#   'Riboflavin_rda': nan,
#   'Satfat_rda': 0.050022,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': "CAMPBELL'S RED & WHITE,FRENCH ONION SOUP,COND",
#   'Sodium_mg': 516.0,
#   'Sodium_rda': 0.2709,
#   'Sugar_Tot_g': 3.17,
#   'Thiamin_mg': nan,
#   'Thiamin_rda': nan,
#   'Totfat_rda': 0.023067692307692306,
#   'Vit_A_IU': 0.0,
#   'Vit_A_RAE': nan,
#   'Vit_B12_pg': nan,
#   'Vit_B6_mg': nan,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.0,
#   'VitaminB12_rda': nan,
#   'VitaminB6_rda': nan,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 91.0,
#   'Zinc_mg': nan,
#   'Zinc_rda': nan,
#   'protein_rda': 0.040068},
#  1406: {'Alpha_Carot_pg': nan,
#   'Ash_g': 0.72,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 0.0,
#   'Calcium_rda': 0.0,
#   'Calories': 80.6,
#   'Calories_rda': 0.0403,
#   'Carbohydrt_g': 8.06,
#   'Cholestrl_mg': 0.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.0,
#   'Copper_mg': nan,
#   'Copper_rda': nan,
#   'Dietfiber_rda': 0.03968,
#   'Energ_Kcal': 65,
#   'FA_Mono_g': 0.403,
#   'FA_Poly_g': 1.21,
#   'FA_Sat_g': 0.806,
#   'Fiber_TD_g': 0.8,
#   'Folate_DFE_pg': nan,
#   'Folate_Tot_pg': nan,
#   'Folate_rda': nan,
#   'Folic_Acid_pg': nan,
#   'Food_Folate_pg': nan,
#   'GmWt_1': 124.0,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 serving, 1/2 cup',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': nan,
#   'Iron_rda': nan,
#   'Lipid_Tot_g': 2.82,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': nan,
#   'Magnesium_rda': nan,
#   'Manganese_mg': nan,
#   'Manganese_rda': nan,
#   'Molybdenum_rda': 1.0746666666666667,
#   'NDB_No': 6355,
#   'Niacin_mg': nan,
#   'Niacin_rda': nan,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': nan,
#   'Phosphorus_rda': nan,
#   'Potassium_mg': 548.0,
#   'Potassium_rda': 0.19414857142857145,
#   'Protein_g': 1.61,
#   'Quantity': '1 serving, 1/2 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': nan,
#   'Riboflavin_mg': nan,
#   'Riboflavin_rda': nan,
#   'Satfat_rda': 0.049972,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': "CAMPBELL'S RED & WHITE,GOLDEN MUSHROOM SOUP,COND",
#   'Sodium_mg': 524.0,
#   'Sodium_rda': 0.2707333333333333,
#   'Sugar_Tot_g': 0.81,
#   'Thiamin_mg': nan,
#   'Thiamin_rda': nan,
#   'Totfat_rda': 0.053796923076923076,
#   'Vit_A_IU': 403.0,
#   'Vit_A_RAE': nan,
#   'Vit_B12_pg': nan,
#   'Vit_B6_mg': nan,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.099944,
#   'VitaminB12_rda': nan,
#   'VitaminB6_rda': nan,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 87.2,
#   'Zinc_mg': nan,
#   'Zinc_rda': nan,
#   'protein_rda': 0.039928},
#  1407: {'Alpha_Carot_pg': nan,
#   'Ash_g': 0.8,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': nan,
#   'Calcium_rda': nan,
#   'Calories': 79.38,
#   'Calories_rda': 0.03969,
#   'Carbohydrt_g': 9.52,
#   'Cholestrl_mg': 4.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.016800000000000002,
#   'Copper_mg': nan,
#   'Copper_rda': nan,
#   'Dietfiber_rda': 0.04032,
#   'Energ_Kcal': 63,
#   'FA_Mono_g': 0.794,
#   'FA_Poly_g': 0.397,
#   'FA_Sat_g': 0.397,
#   'Fiber_TD_g': 0.8,
#   'Folate_DFE_pg': nan,
#   'Folate_Tot_pg': nan,
#   'Folate_rda': nan,
#   'Folic_Acid_pg': nan,
#   'Food_Folate_pg': nan,
#   'GmWt_1': 126.0,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 serving, 1/2 cup',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': 0.29,
#   'Iron_rda': 0.0203,
#   'Lipid_Tot_g': 1.59,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': nan,
#   'Magnesium_rda': nan,
#   'Manganese_mg': nan,
#   'Manganese_rda': nan,
#   'Molybdenum_rda': 1.0584,
#   'NDB_No': 6357,
#   'Niacin_mg': nan,
#   'Niacin_rda': nan,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': nan,
#   'Phosphorus_rda': nan,
#   'Potassium_mg': 429.0,
#   'Potassium_rda': 0.15444,
#   'Protein_g': 2.38,
#   'Quantity': '1 serving, 1/2 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': nan,
#   'Riboflavin_mg': nan,
#   'Riboflavin_rda': nan,
#   'Satfat_rda': 0.025011,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': "CAMPBELL'S RED & WHITE,GOLDFISH PASTA W/ CHICK",
#   'Sodium_mg': 381.0,
#   'Sodium_rda': 0.200025,
#   'Sugar_Tot_g': 0.79,
#   'Thiamin_mg': nan,
#   'Thiamin_rda': nan,
#   'Totfat_rda': 0.030821538461538463,
#   'Vit_A_IU': 397.0,
#   'Vit_A_RAE': nan,
#   'Vit_B12_pg': nan,
#   'Vit_B6_mg': nan,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.100044,
#   'VitaminB12_rda': nan,
#   'VitaminB6_rda': nan,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 85.7,
#   'Zinc_mg': nan,
#   'Zinc_rda': nan,
#   'protein_rda': 0.059975999999999995},
#  1408: {'Alpha_Carot_pg': nan,
#   'Ash_g': 1.63,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 74.0,
#   'Calcium_rda': 0.18574,
#   'Calories': 198.29,
#   'Calories_rda': 0.099145,
#   'Carbohydrt_g': 11.73,
#   'Cholestrl_mg': 9.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.07529999999999999,
#   'Copper_mg': 0.056,
#   'Copper_rda': 0.07028,
#   'Dietfiber_rda': 0.020079999999999997,
#   'Energ_Kcal': 79,
#   'FA_Mono_g': 0.75,
#   'FA_Poly_g': 0.49,
#   'FA_Sat_g': 1.25,
#   'Fiber_TD_g': 0.2,
#   'Folate_DFE_pg': 9.0,
#   'Folate_Tot_pg': 9.0,
#   'Folate_rda': 0.05647499999999999,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 9.0,
#   'GmWt_1': 251.0,
#   'GmWt_2': 609.0,
#   'GmWt_Desc1': '1 cup,  (8 fl oz)',
#   'GmWt_Desc2': '1 can,  (11 oz), prepared',
#   'Healthy': nan,
#   'Iron_mg': 0.35,
#   'Iron_rda': 0.04880555555555555,
#   'Lipid_Tot_g': 2.63,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': 10.0,
#   'Magnesium_rda': 0.06275,
#   'Manganese_mg': 0.103,
#   'Manganese_rda': 0.129265,
#   'Molybdenum_rda': 2.6438666666666664,
#   'NDB_No': 6358,
#   'Niacin_mg': 0.499,
#   'Niacin_rda': 0.0626245,
#   'Panto_Acid_mg': 0.2,
#   'PantothenicAcid_rda': 0.050199999999999995,
#   'Phosphorus_mg': 69.0,
#   'Phosphorus_rda': 0.17319,
#   'Potassium_mg': 241.0,
#   'Potassium_rda': 0.17283142857142855,
#   'Protein_g': 2.51,
#   'Quantity': '1 cup,  (8 fl oz)',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 9.0,
#   'Riboflavin_mg': 0.107,
#   'Riboflavin_rda': 0.15798235294117646,
#   'Satfat_rda': 0.156875,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': 'SOUP,TOMATO BISQUE,CND,PREP W/ EQ VOLUME MILK',
#   'Sodium_mg': 442.0,
#   'Sodium_rda': 0.4622583333333333,
#   'Sugar_Tot_g': nan,
#   'Thiamin_mg': 0.045,
#   'Thiamin_rda': 0.07529999999999999,
#   'Totfat_rda': 0.10155846153846153,
#   'Vit_A_IU': 350.0,
#   'Vit_A_RAE': 25.0,
#   'Vit_B12_pg': 0.17,
#   'Vit_B6_mg': 0.056,
#   'Vit_C_mg': 2.8,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.1757,
#   'VitaminB12_rda': 0.07111666666666666,
#   'VitaminB6_rda': 0.07028,
#   'VitaminC_rda': 0.11713333333333331,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 81.51,
#   'Zinc_mg': 0.25,
#   'Zinc_rda': 0.04183333333333333,
#   'protein_rda': 0.12600199999999998},
#  1409: {'Alpha_Carot_pg': 0.0,
#   'Ash_g': 1.38,
#   'Beta_Carot_pg': 115.0,
#   'Beta_Crypt_pg': 0.0,
#   'Calcium_mg': 68.0,
#   'Calcium_rda': 0.17136,
#   'Calories': 138.6,
#   'Calories_rda': 0.0693,
#   'Carbohydrt_g': 9.82,
#   'Cholestrl_mg': 4.0,
#   'Choline_Tot_ mg': 14.7,
#   'Colesterol_rda': 0.033600000000000005,
#   'Copper_mg': 0.027,
#   'Copper_rda': 0.03402,
#   'Dietfiber_rda': 0.0504,
#   'Energ_Kcal': 55,
#   'FA_Mono_g': 0.356,
#   'FA_Poly_g': 0.113,
#   'FA_Sat_g': 0.707,
#   'Fiber_TD_g': 0.5,
#   'Folate_DFE_pg': 2.0,
#   'Folate_Tot_pg': 2.0,
#   'Folate_rda': 0.0126,
#   'Folic_Acid_pg': 0.0,
#   'Food_Folate_pg': 2.0,
#   'GmWt_1': 252.0,
#   'GmWt_2': 31.5,
#   'GmWt_Desc1': '1 serving, 1 cup',
#   'GmWt_Desc2': '1 fl oz',
#   'Healthy': nan,
#   'Iron_mg': 0.3,
#   'Iron_rda': 0.042,
#   'Lipid_Tot_g': 1.24,
#   'Lut+Zea_ pg': 43.0,
#   'Lycopene_pg': 5261.0,
#   'Magnesium_mg': 13.0,
#   'Magnesium_rda': 0.0819,
#   'Manganese_mg': 0.074,
#   'Manganese_rda': 0.09323999999999999,
#   'Molybdenum_rda': 1.8479999999999999,
#   'NDB_No': 6359,
#   'Niacin_mg': 0.461,
#   'Niacin_rda': 0.058086000000000006,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': 63.0,
#   'Phosphorus_rda': 0.15876,
#   'Potassium_mg': 343.0,
#   'Potassium_rda': 0.24696,
#   'Protein_g': 2.42,
#   'Quantity': '1 serving, 1 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': 29.0,
#   'Riboflavin_mg': 0.103,
#   'Riboflavin_rda': 0.15268235294117646,
#   'Satfat_rda': 0.089082,
#   'Selenium_pg': 2.7,
#   'Selenium_rda': 0.09720000000000001,
#   'Shrt_Desc': 'SOUP,TOMATO,CND,PREP W/ EQ VOLUME LOFAT (2%) MILK',
#   'Sodium_mg': 206.0,
#   'Sodium_rda': 0.2163,
#   'Sugar_Tot_g': 6.59,
#   'Thiamin_mg': 0.041,
#   'Thiamin_rda': 0.06888,
#   'Totfat_rda': 0.048073846153846155,
#   'Vit_A_IU': 287.0,
#   'Vit_A_RAE': 38.0,
#   'Vit_B12_pg': 0.28,
#   'Vit_B6_mg': 0.061,
#   'Vit_C_mg': 6.3,
#   'Vit_D_IU': 25.0,
#   'Vit_D_pg': 0.6,
#   'Vit_E_mg': 0.18,
#   'Vit_K_pg': 1.6,
#   'VitaminA_rda': 0.144648,
#   'VitaminB12_rda': 0.11760000000000001,
#   'VitaminB6_rda': 0.07686,
#   'VitaminC_rda': 0.2646,
#   'VitaminD_rda': 0.00378,
#   'VitaminE_rda': 0.01512,
#   'VitaminK_rda': 0.0504,
#   'Water_g': 85.15,
#   'Zinc_mg': 0.34,
#   'Zinc_rda': 0.057120000000000004,
#   'protein_rda': 0.121968},
#  1410: {'Alpha_Carot_pg': nan,
#   'Ash_g': 1.95,
#   'Beta_Carot_pg': nan,
#   'Beta_Crypt_pg': nan,
#   'Calcium_mg': 16.0,
#   'Calcium_rda': 0.02048,
#   'Calories': 180.48,
#   'Calories_rda': 0.09023999999999999,
#   'Carbohydrt_g': 21.88,
#   'Cholestrl_mg': 0.0,
#   'Choline_Tot_ mg': nan,
#   'Colesterol_rda': 0.0,
#   'Copper_mg': nan,
#   'Copper_rda': nan,
#   'Dietfiber_rda': 0.15872,
#   'Energ_Kcal': 141,
#   'FA_Mono_g': 0.391,
#   'FA_Poly_g': 0.781,
#   'FA_Sat_g': 0.781,
#   'Fiber_TD_g': 3.1,
#   'Folate_DFE_pg': nan,
#   'Folate_Tot_pg': nan,
#   'Folate_rda': nan,
#   'Folic_Acid_pg': nan,
#   'Food_Folate_pg': nan,
#   'GmWt_1': 128.0,
#   'GmWt_2': nan,
#   'GmWt_Desc1': '1 serving, 1/2 cup',
#   'GmWt_Desc2': nan,
#   'Healthy': nan,
#   'Iron_mg': 1.13,
#   'Iron_rda': 0.08035555555555554,
#   'Lipid_Tot_g': 2.34,
#   'Lut+Zea_ pg': nan,
#   'Lycopene_pg': nan,
#   'Magnesium_mg': nan,
#   'Magnesium_rda': nan,
#   'Manganese_mg': nan,
#   'Manganese_rda': nan,
#   'Molybdenum_rda': 2.4064,
#   'NDB_No': 6361,
#   'Niacin_mg': nan,
#   'Niacin_rda': nan,
#   'Panto_Acid_mg': nan,
#   'PantothenicAcid_rda': nan,
#   'Phosphorus_mg': nan,
#   'Phosphorus_rda': nan,
#   'Potassium_mg': 305.0,
#   'Potassium_rda': 0.11154285714285715,
#   'Protein_g': 7.03,
#   'Quantity': '1 serving, 1/2 cup',
#   'Refuse_Pct': 0.0,
#   'Retinol_pg': nan,
#   'Riboflavin_mg': nan,
#   'Riboflavin_rda': nan,
#   'Satfat_rda': 0.049984,
#   'Selenium_pg': nan,
#   'Selenium_rda': nan,
#   'Shrt_Desc': "CAMPBELL'S RED & WHITE,GRN PEA SOUP,COND",
#   'Sodium_mg': 680.0,
#   'Sodium_rda': 0.36266666666666664,
#   'Sugar_Tot_g': 4.69,
#   'Thiamin_mg': nan,
#   'Thiamin_rda': nan,
#   'Totfat_rda': 0.046079999999999996,
#   'Vit_A_IU': 156.0,
#   'Vit_A_RAE': nan,
#   'Vit_B12_pg': nan,
#   'Vit_B6_mg': nan,
#   'Vit_C_mg': 0.0,
#   'Vit_D_IU': nan,
#   'Vit_D_pg': nan,
#   'Vit_E_mg': nan,
#   'Vit_K_pg': nan,
#   'VitaminA_rda': 0.039936,
#   'VitaminB12_rda': nan,
#   'VitaminB6_rda': nan,
#   'VitaminC_rda': 0.0,
#   'VitaminD_rda': nan,
#   'VitaminE_rda': nan,
#   'VitaminK_rda': nan,
#   'Water_g': 66.8,
#   'Zinc_mg': nan,
#   'Zinc_rda': nan,
#   'protein_rda': 0.17996800000000002},
#  ...}

# %%
#keep only the top 50 healthy items
dffin = dffin.sort_values('Healthy', ascending=False)
dffin = dffin.head(500)
## Modifying Max calories  to fit my whims
## will loop in nutritionist later
Maxgoodcal = 400
Redboxhigh = 600
Yellowboxlow = 400


def my_text_input_handler(attr, old, new):
    print("Previous label: " + old)
    print("Updated label: " + new)
    

x= dffin.Calories.values.tolist()
h= dffin.Healthy.values.tolist()
y= dffin.Healthy.values.tolist()
n=dffin.Shrt_Desc.values.tolist()
s=dffin.Sodium_mg.values.tolist()
k=dffin.Vit_K_pg.values.tolist()
phos=dffin.Phosphorus_mg.values.tolist()
por=dffin.Quantity.values.tolist()
pro=dffin.Protein_g.values.tolist()
pot=dffin.Potassium_mg.values.tolist()

ylim = max(h)+50
source = ColumnDataSource(data=dict(x=x,y=y,n=n,s=s,h=h,pro=pro,phos=phos, por=por,k=k, pot=pot))
 

    
TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,tap,previewsave,box_select,poly_select,lasso_select,hover"
plot = figure(tools = TOOLS)
plot.scatter('x', 'y', source=source, radius= dffin.Healthy ,line_color=None)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var S = salt.value;
    var Prot = protein.value;
    var Phos = phosphorus.value;
    var K = vit_k.value;
    var Pot = pot.value;
    
    h = data['h']
    x = data['x']
    y = data['y']
    s = data['s']
    k = data['k']
    pot = data['pot']
    pro = data['pro']
    phos = data['phos']
    por = data['por']
    


for (i = 0; i < x.length; i++) {
        y[i] =  h[i]-((s[i]-100)*S)- ((pro[i]- 10)*Prot *3) - ((phos[i]- 100)*Phos *2) - ((k[i] - 200)* K *1 ) - ((pot[i] - 200)* Pot *1 );
        
        if (y[i] < 0) {
            y[i] = 0
            }   
        }
    
    source.trigger('change');
""")


salt_slider = Slider(start=0, end=1, value=0, step=.005, title="Salt", callback=callback)
callback.args["salt"] = salt_slider

protein_slider = Slider(start=0, end=1, value=0, step=.005, title="Protein", callback=callback)
callback.args["protein"] = protein_slider

phos_slider = Slider(start=0, end=1, value=0, step=.005, title="Phosphorus", callback=callback)
callback.args["phosphorus"] = phos_slider

k_slider = Slider(start=0, end=1, value=0, step=.005, title="Vitamin K", callback=callback)
callback.args["vit_k"] = k_slider

pot_slider = Slider(start=0, end=1, value=0, step=.005, title="Potassium", callback=callback)
callback.args["pot"] = pot_slider

text_input = TextInput(value="", title="Food to Search for :")
text_input.on_change("value", my_text_input_handler)

#Selectthis = text_input
# = select[dff.Shrt_Desc.str.contains(Selectthis) == False]


hover = plot.select(dict(type=HoverTool))
hover.tooltips = OrderedDict([('Food', '@n'),('Nutrition', '@y'),('Sodium', '@s'),('Phosphorus', '@phos'),('Calories', '@x'),('Protein', '@pro'),('Potassium', '@pot'),('Vitamin K', '@k'),('Quantity','@por')])


#controls = [food]
#for control in controls:
#    control.on_change('value', lambda attr, old, new: update())

#inputs = widgetbox(salt_slider,protein_slider, phos_slider, k_slider, pot_slider) #, food)
 
layout = row(
    plot,
    widgetbox(text_input,salt_slider,protein_slider, phos_slider, k_slider, pot_slider),
)

high_box = BoxAnnotation( left=Redboxhigh, fill_alpha=0.1, fill_color='red')
mid_box = BoxAnnotation( left=Yellowboxlow, right=Redboxhigh, fill_alpha=0.1, fill_color='yellow')
low_box = BoxAnnotation( right=Yellowboxlow, fill_alpha=0.1, fill_color='green')

plot.add_layout(low_box)
plot.add_layout(mid_box)
plot.add_layout(high_box)

plot.title.text = "Nutrition Filter"
#p.xgrid[0].grid_line_color=None
#p.ygrid[0].grid_line_alpha=0.5
plot.xaxis.axis_label = 'Calories(lower tends to be better)'
plot.yaxis.axis_label = 'Healthy (Higher is Better)'

output_file("ffslidertext.html", title="Food Filters")


show(layout)
# Out:
# INFO:bokeh.core.state:Session output file 'ffslidertext.html' already exists, will be overwritten.

# %%
#df["Quantity"] = df["GmWt_1"].map(str) + " @ " + df["GmWt_Desc1"]

#dffin['Healthy'][dffin['Calories' > Maxgoodcal].map()

# %%
df["Quantity"] = df["GmWt_1"].map(str)

# %%
df.GmWt_Desc1.head()

# %%
df.Quantity.head(25)

# %%
dff['Phosphorus_mg']

# %%
#print("rgb("+ str(random.randint(0,255)) + "," + str(random.randint(0,255)) + "," + str(random.randint(0,255)) + ")")
#df.columns
#df.Healthy
#df.head().totalcal
#for i in df["foodgroup"]:
  # df["grpnumbers"] = grphash[df["foodgroup"][i]]
    
#grpdict
#grpdict["Burger"]
#grpdict

# %%
#len(dffin)

# %%
x.length

# %%
#df.Shrt_Desc.head()
#df['foodgroup'] = df[df['Shrt_Desc'].str.contains("BUTTER|MILK")==TRUE
#df.foodgroup.head()

#converter = {}
#i=1
#for item in df["foodgroup"]:
#    if item not in converter:
        #converter[item] =i
#        converter[item]= "rgb("+ str(random.randint(0,255)) + "," + str(random.randint(0,255)) + "," + str(random.randint(0,255)) + ")"
#        i += 1
#df['foodgrpnum'] = [converter[i] for i in df["foodgroup"]]
#print("rgb("+ str(random.randint(0,255)) + "," + str(random.randint(0,255)) + "," + str(random.randint(0,255)) + ")")
#df.foodgrpnum

# %%
#TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,tap,previewsave,box_select,poly_select,lasso_select"

#output_file("color_scatter.html", title="color_scatter.py example")

#p = figure(tools=TOOLS)
#p.scatter(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

#x=dffin.Healthy.values.tolist()
#y = dffin.Calories.values.tolist()

#p.annulus(x, y, inner_radius=0, outer_radius=2,color="orange", alpha=0.6)

#p.annulus(x=dffin.Calories_rda.tolist(), y=dffin.Healthy, inner_radius=0.1, outer_radius=0.25, color="orange", alpha=0.6)
#p.scatter(x,y, radius= 1 , fill_alpha=0.6, line_color=None)
#show(p)

# %%
# plot({
#    'data': [
#        Scatter(x=dffin['Calories_rda'],
#                y=dffin['Healthy'],
#                text=dffin.foodtext ,
##                #marker=Marker(size=df['calperserv'], sizemode='area'),   #, sizeref=131868,),
 #               marker = dict(size= dffin.Healthy ,
#                    line= dict(width=1),
#                    color= "rgb(178,16,243)" ,
#                    opacity= 0.8
#                   ),
#                #name= y[i],
#                #mode='markers'
##                mode="markers"
#               ) 
#    ],
#    'layout': Layout(title='Nutrition and Calorie Count',xaxis=XAxis(title='Calories per Serving'), yaxis=YAxis(title='Nutrition 1-10'))
#}, show_link=False)
